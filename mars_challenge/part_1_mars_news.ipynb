# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Downloading: 100%|█| 6.58M/6.58M [00:01<00:00, 5.67MB/s

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
html = browser.html
text_soup = soup(html, 'html.parser')

# %%
# Extract all the text elements
text_elements = text_soup.find_all('div', class_='list_text')

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Create an empty list to store the dictionaries
mars_dict ={}
titles_prevs = []

# %%
# Loop through the text elements
# Extract the title and preview text from the elements
# Store each title and preview pair in a dictionary
# Add the dictionary to the list
for x in text_elements:
    title = x.find('div', class_='content_title').text
    prev_text = x.find('div', class_='article_teaser_body').text
    mars_dict = {'Title': title, 'Preview': prev_text}
    titles_prevs.append(mars_dict)

# %%
# Print the list to confirm success
titles_prevs
# Out:
# [{'Title': 'Heat and Dust Help Launch Martian Water Into Space, Scientists Find',
#   'Preview': 'Scientists using an instrument aboard NASA’s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible. '},
#  {'Title': "Common Questions about InSight's 'Mole'",
#   'Preview': 'The following Q&As with members of the team answer some of the most common questions about the burrowing device, part of a science instrument called the Heat Flow and Physical Properties Package (HP3).'},
#  {'Title': "NASA's Curiosity Takes Selfie With 'Mary Anning' on the Red Planet",
#   'Preview': 'The Mars rover has drilled three samples of rock in this clay-enriched region since arriving in July.'},
#  {'Title': "NASA's Mars Rover Drivers Need Your Help",
#   'Preview': 'Using an online tool to label Martian terrain types, you can train an artificial intelligence algorithm that could improve the way engineers guide the Curiosity rover.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Preview': 'Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.'},
#  {'Title': 'Mars Is Getting a New Robotic Meteorologist',
#   'Preview': "Sensors on NASA's Perseverance will help prepare for future human exploration by taking weather measurements and studying dust particles."},
#  {'Title': "Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch",
#   'Preview': "A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment — including the rover's sample collection tubes — to Florida for this summer's liftoff."},
#  {'Title': 'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team',
#   'Preview': 'The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.'},
#  {'Title': "NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'",
#   'Preview': 'A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.'},
#  {'Title': "NASA's Treasure Map for Water Ice on Mars",
#   'Preview': 'A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.'},
#  {'Title': "NASA's Mars Perseverance Rover Passes Flight Readiness Review",
#   'Preview': "\u200bThe agency's Mars 2020 mission has one more big prelaunch review – the Launch Readiness Review, on July 27."},
#  {'Title': "NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound",
#   'Preview': "The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet."},
#  {'Title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'Preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'Title': "NASA's Push to Save the Mars InSight Lander's Heat Probe",
#   'Preview': "The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the mole against the wall of its hole."},
#  {'Title': "NASA's Mars 2020 Will Hunt for Microscopic Fossils",
#   'Preview': "A new paper identifies a ring of minerals at the rover's landing site that are ideal for fossilizing microbial life."},
#  {'Title': 'Heat and Dust Help Launch Martian Water Into Space, Scientists Find',
#   'Preview': 'Scientists using an instrument aboard NASA’s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible. '},
#  {'Title': "Common Questions about InSight's 'Mole'",
#   'Preview': 'The following Q&As with members of the team answer some of the most common questions about the burrowing device, part of a science instrument called the Heat Flow and Physical Properties Package (HP3).'},
#  {'Title': "NASA's Curiosity Takes Selfie With 'Mary Anning' on the Red Planet",
#   'Preview': 'The Mars rover has drilled three samples of rock in this clay-enriched region since arriving in July.'},
#  {'Title': "NASA's Mars Rover Drivers Need Your Help",
#   'Preview': 'Using an online tool to label Martian terrain types, you can train an artificial intelligence algorithm that could improve the way engineers guide the Curiosity rover.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Preview': 'Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.'},
#  {'Title': 'Mars Is Getting a New Robotic Meteorologist',
#   'Preview': "Sensors on NASA's Perseverance will help prepare for future human exploration by taking weather measurements and studying dust particles."},
#  {'Title': "Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch",
#   'Preview': "A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment — including the rover's sample collection tubes — to Florida for this summer's liftoff."},
#  {'Title': 'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team',
#   'Preview': 'The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.'},
#  {'Title': "NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'",
#   'Preview': 'A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.'},
#  {'Title': "NASA's Treasure Map for Water Ice on Mars",
#   'Preview': 'A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.'},
#  {'Title': "NASA's Mars Perseverance Rover Passes Flight Readiness Review",
#   'Preview': "\u200bThe agency's Mars 2020 mission has one more big prelaunch review – the Launch Readiness Review, on July 27."},
#  {'Title': "NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound",
#   'Preview': "The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet."},
#  {'Title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'Preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'Title': "NASA's Push to Save the Mars InSight Lander's Heat Probe",
#   'Preview': "The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the mole against the wall of its hole."},
#  {'Title': "NASA's Mars 2020 Will Hunt for Microscopic Fossils",
#   'Preview': "A new paper identifies a ring of minerals at the rover's landing site that are ideal for fossilizing microbial life."},
#  {'Title': 'Heat and Dust Help Launch Martian Water Into Space, Scientists Find',
#   'Preview': 'Scientists using an instrument aboard NASA’s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible. '},
#  {'Title': "Common Questions about InSight's 'Mole'",
#   'Preview': 'The following Q&As with members of the team answer some of the most common questions about the burrowing device, part of a science instrument called the Heat Flow and Physical Properties Package (HP3).'},
#  {'Title': "NASA's Curiosity Takes Selfie With 'Mary Anning' on the Red Planet",
#   'Preview': 'The Mars rover has drilled three samples of rock in this clay-enriched region since arriving in July.'},
#  {'Title': "NASA's Mars Rover Drivers Need Your Help",
#   'Preview': 'Using an online tool to label Martian terrain types, you can train an artificial intelligence algorithm that could improve the way engineers guide the Curiosity rover.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Preview': 'Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.'},
#  {'Title': 'Mars Is Getting a New Robotic Meteorologist',
#   'Preview': "Sensors on NASA's Perseverance will help prepare for future human exploration by taking weather measurements and studying dust particles."},
#  {'Title': "Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch",
#   'Preview': "A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment — including the rover's sample collection tubes — to Florida for this summer's liftoff."},
#  {'Title': 'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team',
#   'Preview': 'The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.'},
#  {'Title': "NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'",
#   'Preview': 'A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.'},
#  {'Title': "NASA's Treasure Map for Water Ice on Mars",
#   'Preview': 'A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.'},
#  {'Title': "NASA's Mars Perseverance Rover Passes Flight Readiness Review",
#   'Preview': "\u200bThe agency's Mars 2020 mission has one more big prelaunch review – the Launch Readiness Review, on July 27."},
#  {'Title': "NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound",
#   'Preview': "The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet."},
#  {'Title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'Preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'Title': "NASA's Push to Save the Mars InSight Lander's Heat Probe",
#   'Preview': "The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the mole against the wall of its hole."},
#  {'Title': "NASA's Mars 2020 Will Hunt for Microscopic Fossils",
#   'Preview': "A new paper identifies a ring of minerals at the rover's landing site that are ideal for fossilizing microbial life."}]

# %%
browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON
import json
import pandas as pd
with open("mars.json", "w") as outfile:
    json.dump(titles_prevs, outfile)
pd.read_json("mars.json")
# Out:
#                                                 Title  \
# 0   Heat and Dust Help Launch Martian Water Into S...
# 1             Common Questions about InSight's 'Mole'
# 2   NASA's Curiosity Takes Selfie With 'Mary Annin...
# 3            NASA's Mars Rover Drivers Need Your Help
# 4   How NASA's Perseverance Mars Team Adjusted to ...
# 5         Mars Is Getting a New Robotic Meteorologist
# 6   Air Deliveries Bring NASA's Perseverance Mars ...
# 7   NASA Adds Return Sample Scientists to Mars 202...
# 8   NASA's Perseverance Rover Will Look at Mars Th...
# 9           NASA's Treasure Map for Water Ice on Mars
# 10  NASA's Mars Perseverance Rover Passes Flight R...
# 11  NASA's Perseverance Rover Goes Through Trials ...
# 12  NASA Prepares for Moon and Mars With New Addit...
# 13  NASA's Push to Save the Mars InSight Lander's ...
# 14  NASA's Mars 2020 Will Hunt for Microscopic Fos...
# 15  Heat and Dust Help Launch Martian Water Into S...
# 16            Common Questions about InSight's 'Mole'
# 17  NASA's Curiosity Takes Selfie With 'Mary Annin...
# 18           NASA's Mars Rover Drivers Need Your Help
# 19  How NASA's Perseverance Mars Team Adjusted to ...
# 20        Mars Is Getting a New Robotic Meteorologist
# 21  Air Deliveries Bring NASA's Perseverance Mars ...
# 22  NASA Adds Return Sample Scientists to Mars 202...
# 23  NASA's Perseverance Rover Will Look at Mars Th...
# 24          NASA's Treasure Map for Water Ice on Mars
# 25  NASA's Mars Perseverance Rover Passes Flight R...
# 26  NASA's Perseverance Rover Goes Through Trials ...
# 27  NASA Prepares for Moon and Mars With New Addit...
# 28  NASA's Push to Save the Mars InSight Lander's ...
# 29  NASA's Mars 2020 Will Hunt for Microscopic Fos...
# 30  Heat and Dust Help Launch Martian Water Into S...
# 31            Common Questions about InSight's 'Mole'
# 32  NASA's Curiosity Takes Selfie With 'Mary Annin...
# 33           NASA's Mars Rover Drivers Need Your Help
# 34  How NASA's Perseverance Mars Team Adjusted to ...
# 35        Mars Is Getting a New Robotic Meteorologist
# 36  Air Deliveries Bring NASA's Perseverance Mars ...
# 37  NASA Adds Return Sample Scientists to Mars 202...
# 38  NASA's Perseverance Rover Will Look at Mars Th...
# 39          NASA's Treasure Map for Water Ice on Mars
# 40  NASA's Mars Perseverance Rover Passes Flight R...
# 41  NASA's Perseverance Rover Goes Through Trials ...
# 42  NASA Prepares for Moon and Mars With New Addit...
# 43  NASA's Push to Save the Mars InSight Lander's ...
# 44  NASA's Mars 2020 Will Hunt for Microscopic Fos...
#
#                                               Preview
# 0   Scientists using an instrument aboard NASA’s M...
# 1   The following Q&As with members of the team an...
# 2   The Mars rover has drilled three samples of ro...
# 3   Using an online tool to label Martian terrain ...
# 4   Like much of the rest of the world, the Mars r...
# 5   Sensors on NASA's Perseverance will help prepa...
# 6   A NASA Wallops Flight Facility cargo plane tra...
# 7   The leadership council for Mars 2020 science a...
# 8   A pair of zoomable cameras will help scientist...
# 9   A new study identifies frozen water just below...
# 10  ​The agency's Mars 2020 mission has one more b...
# 11  The agency's new Mars rover is put through a s...
# 12  Robotic spacecraft will be able to communicate...
# 13  The scoop on the end of the spacecraft's robot...
# 14  A new paper identifies a ring of minerals at t...
# 15  Scientists using an instrument aboard NASA’s M...
# 16  The following Q&As with members of the team an...
# 17  The Mars rover has drilled three samples of ro...
# 18  Using an online tool to label Martian terrain ...
# 19  Like much of the rest of the world, the Mars r...
# 20  Sensors on NASA's Perseverance will help prepa...
# 21  A NASA Wallops Flight Facility cargo plane tra...
# 22  The leadership council for Mars 2020 science a...
# 23  A pair of zoomable cameras will help scientist...
# 24  A new study identifies frozen water just below...
# 25  ​The agency's Mars 2020 mission has one more b...
# 26  The agency's new Mars rover is put through a s...
# 27  Robotic spacecraft will be able to communicate...
# 28  The scoop on the end of the spacecraft's robot...
# 29  A new paper identifies a ring of minerals at t...
# 30  Scientists using an instrument aboard NASA’s M...
# 31  The following Q&As with members of the team an...
# 32  The Mars rover has drilled three samples of ro...
# 33  Using an online tool to label Martian terrain ...
# 34  Like much of the rest of the world, the Mars r...
# 35  Sensors on NASA's Perseverance will help prepa...
# 36  A NASA Wallops Flight Facility cargo plane tra...
# 37  The leadership council for Mars 2020 science a...
# 38  A pair of zoomable cameras will help scientist...
# 39  A new study identifies frozen water just below...
# 40  ​The agency's Mars 2020 mission has one more b...
# 41  The agency's new Mars rover is put through a s...
# 42  Robotic spacecraft will be able to communicate...
# 43  The scoop on the end of the spacecraft's robot...
# 44  A new paper identifies a ring of minerals at t...

# %%
# Export data to MongoDB
